# %%
import tensorflow as tf
from tensorflow.keras import layers, models 
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import os
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns
import numpy as np
from tensorflow.keras.models import load_model

# %%
# ====================
# Settings
# ====================
DATA_DIR = "C:\\Users\\peter\\Documents\\internship\\DATASET"
IMG_SIZE = (224, 224)
BATCH_SIZE = 128
SEED = 42
EPOCHS = 50
VAL_SPLIT = 0.2
TEST_SPLIT = 0.1

# ====================
# Load full dataset
# ====================
full_ds = tf.keras.utils.image_dataset_from_directory(
    DATA_DIR,
    label_mode='categorical',   # one-hot labels
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True
)
# Out:
# Found 1203 files belonging to 4 classes.

# %%
# ====================
# Compute dataset sizes for split
# ====================
dataset_size = tf.data.experimental.cardinality(full_ds).numpy()
test_size = int(TEST_SPLIT * dataset_size)
train_val_size = dataset_size - test_size
val_size = int(VAL_SPLIT * train_val_size)
train_size = train_val_size - val_size

# ====================
# Split into train/val/test
# ====================
train_val_ds = full_ds.take(train_val_size)
test_ds = full_ds.skip(train_val_size)

val_ds = train_val_ds.take(val_size)
train_ds = train_val_ds.skip(val_size)

# Prefetch for performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

# ====================
# Data augmentation
# ====================
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1)
])
# ====================
# Callbacks
# ====================
checkpoint = ModelCheckpoint("best_model.keras", monitor="val_accuracy", save_best_only=True, verbose=1)

# %%
# ====================
# EfficientNetB0 base
# ====================
base_model = EfficientNetB0(include_top=False, input_shape=IMG_SIZE + (3,), weights="imagenet")
base_model.trainable = False  # freeze base


# ====================
# Build model
# ====================
inputs = tf.keras.Input(shape=IMG_SIZE + (3,))
x = data_augmentation(inputs)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation="relu")(x)
x = layers.BatchNormalization()(x)  # batch norm after dense
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(4, activation="softmax")(x)

model = models.Model(inputs, outputs)

# %%
# ====================
# Compile model
# ====================
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# ====================
# Train
# ====================
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[checkpoint]
)

# ====================
# Plot accuracy/loss
# ====================
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='train_acc')
plt.plot(history.history['val_accuracy'], label='val_acc')
plt.title('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.title('Loss')
plt.legend()

plt.show()
# Out:
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3988 - loss: 1.9316
# Epoch 1: val_accuracy improved from None to 0.71875, saving model to best_modelNT.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 27s 3s/step - accuracy: 0.5459 - loss: 1.3927 - val_accuracy: 0.7188 - val_loss: 0.7890
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7606 - loss: 0.7013
# Epoch 2: val_accuracy improved from 0.71875 to 0.75781, saving model to best_modelNT.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.7773 - loss: 0.6658 - val_accuracy: 0.7578 - val_loss: 0.6398
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8449 - loss: 0.4653
# Epoch 3: val_accuracy improved from 0.75781 to 0.79688, saving model to best_modelNT.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8242 - loss: 0.5249 - val_accuracy: 0.7969 - val_loss: 0.6391
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8402 - loss: 0.4322
# Epoch 4: val_accuracy improved from 0.79688 to 0.81250, saving model to best_modelNT.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.8350 - loss: 0.4410 - val_accuracy: 0.8125 - val_loss: 0.5112
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8916 - loss: 0.3262
# Epoch 5: val_accuracy improved from 0.81250 to 0.86719, saving model to best_modelNT.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.8633 - loss: 0.3882 - val_accuracy: 0.8672 - val_loss: 0.4079
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8597 - loss: 0.3894
# Epoch 6: val_accuracy improved from 0.86719 to 0.90625, saving model to best_modelNT.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.8652 - loss: 0.3715 - val_accuracy: 0.9062 - val_loss: 0.3789
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8699 - loss: 0.3563
# Epoch 7: val_accuracy did not improve from 0.90625
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8740 - loss: 0.3478 - val_accuracy: 0.8594 - val_loss: 0.4491
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8821 - loss: 0.3314
# Epoch 8: val_accuracy improved from 0.90625 to 0.91406, saving model to best_modelNT.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.8936 - loss: 0.3088 - val_accuracy: 0.9141 - val_loss: 0.3745
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8903 - loss: 0.3191
# Epoch 9: val_accuracy did not improve from 0.91406
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.8936 - loss: 0.2998 - val_accuracy: 0.8672 - val_loss: 0.3342
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9016 - loss: 0.2859
# Epoch 10: val_accuracy improved from 0.91406 to 0.93750, saving model to best_modelNT.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.9111 - loss: 0.2554 - val_accuracy: 0.9375 - val_loss: 0.3098
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.
val_accuracy did not improve from 0.98438
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.9619 - loss: 0.1037 - val_accuracy: 0.9375 - val_loss: 0.1330
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9615 - loss: 0.1170
# Epoch 34: val_accuracy did not improve from 0.98438
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.9590 - loss: 0.1213 - val_accuracy: 0.9766 - val_loss: 0.1350
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9620 - loss: 0.1079
# Epoch 35: val_accuracy did not improve from 0.98438
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.9639 - loss: 0.1057 - val_accuracy: 0.9766 - val_loss: 0.1108
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9625 - loss: 0.1009
# Epoch 36: val_accuracy did not improve from 0.98438
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.9648 - loss: 0.1021 - val_accuracy: 0.9688 - val_loss: 0.0992
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9621 - loss: 0.1040
# Epoch 37: val_accuracy did not improve from 0.98438
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.9678 - loss: 0.0974 - val_accuracy: 0.9766 - val_loss: 0.1016
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9605 - loss: 0.1163
# Epoch 38: val_accuracy did not improve from 0.98438
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.9639 - loss: 0.1123 - val_accuracy: 0.9766 - val_loss: 0.1102
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9721 - loss: 0.0910
# Epoch 39: val_accuracy did not improve from 0.98438
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9717 - loss: 0.0963 - val_accuracy: 0.9531 - val_loss: 0.1128
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9606 - loss: 0.1057
# Epoch 40: val_accuracy did not improve from 0.98438
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9629 - loss: 0.1001 - val_accuracy: 0.9531 - val_loss: 0.1269
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9680 - loss: 0.1030
# Epoch 41: val_accuracy did not improve from 0.98438
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9697 - loss: 0.1030 - val_accuracy: 0.9609 - val_loss: 0.1153
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9778 - loss: 0.0953
# Epoch 42: val_accuracy did not improve from 0.98438
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9766 - loss: 0.0887 - val_accuracy: 0.9688 - val_loss: 0.1111
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9701 - loss: 0.1026
# Epoch 43: val_accuracy did not improve from 0.98438
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9697 - loss: 0.1065 - val_accuracy: 0.9844 - val_loss: 0.0804
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9727 - loss: 0.0940
# Epoch 44: val_accuracy did not improve from 0.98438
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.9717 - loss: 0.1038 - val_accuracy: 0.9688 - val_loss: 0.0811
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9642 - loss: 0.1096
# Epoch 45: val_accuracy did not improve from 0.98438
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.9648 - loss: 0.1111 - val_accuracy: 0.9766 - val_loss: 0.0683
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9641 - loss: 0.0854
# Epoch 46: val_accuracy did not improve from 0.98438
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9668 - loss: 0.0935 - val_accuracy: 0.9766 - val_loss: 0.0799
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9740 - loss: 0.0698
# Epoch 47: val_accuracy did not improve from 0.98438
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.9727 - loss: 0.0750 - val_accuracy: 0.9844 - val_loss: 0.0714
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9748 - loss: 0.0757
# Epoch 48: val_accuracy did not improve from 0.98438
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9688 - loss: 0.0825 - val_accuracy: 0.9844 - val_loss: 0.0744
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9788 - loss: 0.0638
# Epoch 49: val_accuracy did not improve from 0.98438
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9795 - loss: 0.0704 - val_accuracy: 0.9609 - val_loss: 0.0880
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9799 - loss: 0.0729
# Epoch 50: val_accuracy did not improve from 0.98438
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step - accuracy: 0.9756 - loss: 0.0856 - val_accuracy: 0.9844 - val_loss: 0.0758

# %%
best_model = load_model("best_modelNT.keras")
best_model.save("model_normaltraining.keras")

# %%
model = load_model("model_normaltraining.keras")
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# ====================
# Evaluate on test set
# ====================
test_loss, test_acc = model.evaluate(test_ds)
print("Test Accuracy:", test_acc)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9804 - loss: 0.1814
# Test Accuracy: 0.9803921580314636

# %%
# 2️⃣ Get class names from your folder structure
DATA_DIR = "C:\\Users\\peter\\Documents\\internship\\DATASET"
class_names = sorted([d for d in os.listdir(DATA_DIR) if os.path.isdir(os.path.join(DATA_DIR, d))])
print("Classes:", class_names)
# 3️⃣ Collect all test images and labels
test_images, test_labels = [], []

for images, labels in val_ds:  # or your test_ds
    test_images.append(images.numpy())
    test_labels.append(labels.numpy())

test_images = np.vstack(test_images)
test_labels = np.vstack(test_labels)

# 4️⃣ Predict classes
pred_probs = model.predict(test_images)
pred_classes = np.argmax(pred_probs, axis=1)
true_classes = np.argmax(test_labels, axis=1)

# 5️⃣ Confusion matrix
cm = confusion_matrix(true_classes, pred_classes)
plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Classes: ['clear skin', 'dark spots', 'puffy eyes', 'wrinkles']
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 448ms/step
